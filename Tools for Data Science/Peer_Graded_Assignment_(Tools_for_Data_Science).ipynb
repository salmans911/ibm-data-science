# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Salman Shanavas**
# <br>
# Software Developer

# %% [markdown]
# *I am interested in data science because of the possibilities it brings with it, for example, looking at data and figuring out new information and taking action based on the new information to improve some aspect of something in this world. I am also interested in data science as it uncovers hidden aspects of the world we normally wouldn't have thought of if we looked at the data ourselves.*

# %% [markdown]
# ### I am going to attempt to print the classic Hello World in the cell below.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# This is an example of a bulleted list of fruits
#
# 1.   Apples
# 2.   Oranges
# 3.   Bananas
#
# This is an example of a horizontal rules
#
# ---
#
# This is an image of a cat![kitten-510651.jpg](data:image/jpeg;base64,...)
